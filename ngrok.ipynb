# %%
# !pip install pyngrok
# !pip install streamlit
from pyngrok import ngrok
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import subprocess
subprocess.Popen(["streamlit", "run", "src/app.py", "--server.port", "8501"])
# Out:
# <Popen: returncode: None args: ['streamlit', 'run', 'src/app.py', '--server....>

# %%
# Pega tu token aquí
ngrok.set_auth_token("327FGaJoNDGk39zhPO9NwQMiQHo_6qqUWvdd5yymPYaE6rJ5Z")

# %%
# Solo se ejecuta la primera vez: el tunel se mantiene
public_url = ngrok.connect(8501)
print("Abre tu app aquí:", public_url)
# Out:
# t=2025-11-19T15:31:38-0500 lvl=eror msg="unable to evaluate ngrok agent binary path for symlinks" obj=tunnels.session err="CreateFile C:\\Users\\erick\\AppData\\Local\\ngrok\\ngrok.exe: The system cannot find the file specified."
# Abre tu app aquí: NgrokTunnel: "https://e9464c01a71c.ngrok-free.app" -> "http://localhost:8501"

# %%
ngrok.kill()
